# %%
from utils_image import *
import matplotlib.pyplot as plt

# %%
import glob, os
os.chdir("C:/Users/Florian Bettini/Desktop/5 - 3A Centrale/2 - Option OMA/10 - VIC/Cours/2 - Project/Dataset/FASSEG-multipose01/Test_labels/+30/")
for file in glob.glob("*.bmp"):
    print('')
    print(file)
    img = plt.imread('C:/Users/Florian Bettini/Desktop/5 - 3A Centrale/2 - Option OMA/10 - VIC/Cours/2 - Project/Dataset/FASSEG-multipose01/Test_labels/+30/' + file)
    plt.figure(figsize=(15,5))

    plt.subplot(1,3,1)
    plt.title('labels')
    plt.imshow(img, cmap='gray')

    plt.subplot(1,3,2)
    plt.title('relabeled')
    img_label = label_image(img)
    plt.imshow(img_label, cmap='gray')

    coordinates = find_points(img_label)
    im = head_pose(img, coordinates)
    plt.subplot(1,3,3)
    plt.title('head pose')
    plt.imshow(im, cmap='gray')
    plt.show()
# Out:
# personne08148+0+30.bmp
# Coordinates for Right mouth corner are [189 394]
# Coordinates for Left mouth corner are [101 390]
# Coordinates for Right eye corner are [233 258]
# Coordinates for Left eye corner are [ 66 256]
# Coordinates for nose tip are (131, 331)
# Coordinates for chin are (135, 467)
# personne08248+0+30.bmp
# Coordinates for Right mouth corner are [199 393]
# Coordinates for Left mouth corner are [102 394]
# Coordinates for Right eye corner are [246 248]
# Coordinates for Left eye corner are [ 65 253]
# Coordinates for nose tip are (134, 336)
# Coordinates for chin are (139, 473)
# personne09148+0+30.bmp
# Coordinates for Right mouth corner are [131 395]
# Coordinates for Left mouth corner are [ 58 401]
# Coordinates for Right eye corner are [171 260]
# Coordinates for Left eye corner are [ 29 265]
# Coordinates for nose tip are (76, 344)
# Coordinates for chin are (83, 473)
# personne09248+0+30.bmp
# Coordinates for Right mouth corner are [228 400]
# ...

# %%
import glob, os
os.chdir("C:/Users/Florian Bettini/Desktop/5 - 3A Centrale/2 - Option OMA/10 - VIC/Cours/2 - Project/Dataset/FASSEG-multipose01/Test_labels/-30/")
for file in glob.glob("*.bmp"):
    print('')
    print(file)
    img = plt.imread('C:/Users/Florian Bettini/Desktop/5 - 3A Centrale/2 - Option OMA/10 - VIC/Cours/2 - Project/Dataset/FASSEG-multipose01/Test_labels/-30/' + file)
    plt.figure(figsize=(15,5))

    plt.subplot(1,3,1)
    plt.title('labels')
    plt.imshow(img, cmap='gray')

    plt.subplot(1,3,2)
    plt.title('relabeled')
    img_label = label_image(img)
    plt.imshow(img_label, cmap='gray')

    coordinates = find_points(img_label)
    im = head_pose(img, coordinates)
    plt.subplot(1,3,3)
    plt.title('head pose')
    plt.imshow(im, cmap='gray')
    plt.show()
# Out:
# personne08144+0-30.bmp
# Coordinates for Right mouth corner are [341 394]
# Coordinates for Left mouth corner are [251 388]
# Coordinates for Right eye corner are [374 254]
# Coordinates for Left eye corner are [215 246]
# Coordinates for nose tip are (312, 328)
# Coordinates for chin are (299, 469)
# personne08244+0-30.bmp
# Coordinates for Right mouth corner are [377 395]
# Coordinates for Left mouth corner are [278 392]
# Coordinates for Right eye corner are [406 237]
# Coordinates for Left eye corner are [226 240]
# Coordinates for nose tip are (348, 327)
# Coordinates for chin are (353, 480)
# personne09144+0-30.bmp
# Coordinates for Right mouth corner are [294 401]
# Coordinates for Left mouth corner are [204 403]
# Coordinates for Right eye corner are [335 276]
# Coordinates for Left eye corner are [169 279]
# Coordinates for nose tip are (255, 349)
# Coordinates for chin are (241, 471)
# personne09244+0-30.bmp
# Coordinates for Right mouth corner are [306 383]
# ...
